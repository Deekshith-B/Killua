# %% [markdown]
# # Topic-Player analysis

# %% [markdown]
# # Problem statement - 'Lebron James' vs 'Kobe Bryant' vs 'Michael Jordan'.Who is the GOAT?
#     Michael Jordan, Kobe Bryant, and Lebron James are notorious NBA (National Basketball Association) All-Stars, each with impressive careers. Below we will analyze points scored per game over the course of their entire career. We will analyze min/max/avg and ultimatly determine... "Who is 'The King of The Court'?"

# %% [markdown]
# ## Task Performed -
#     Loading , Cleaning and Analysing the data.
#     Handling the NaN values in the data.
#     Performing analysis analytically and graphically to conclude the best player overall
#     Performing analysis analytically and graphically to know who is the best player in terms of defensive record and offensive player

# %% [markdown]
# #### 1. Importing all the libriaries to perform analysis.

# %%
import numpy as np`
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
advst=pd.read_csv('totals_stats.csv')
advst
# Out:
#      Season  Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...  DRB  TRB  AST  \
# 0   2003-04   19  CLE  NBA  SG  79  79  3122  622  1492  ...  333  432  465
# 1   2004-05   20  CLE  NBA  SF  80  80  3388  795  1684  ...  477  588  577
# 2   2005-06   21  CLE  NBA  SF  79  79  3361  875  1823  ...  481  556  521
# 3   2006-07   22  CLE  NBA  SF  78  78  3190  772  1621  ...  443  526  470
# 4   2007-08   23  CLE  NBA  SF  75  74  3027  794  1642  ...  459  592  539
# ..      ...  ...  ...  ...  ..  ..  ..   ...  ...   ...  ...  ...  ...  ...
# 87  2007-08   29  LAL  NBA  SG  21  21   863  222   463  ...  101  119  117
# 88  2008-09   30  LAL  NBA  SG  23  23   940  242   530  ...  104  123  126
# 89  2009-10   31  LAL  NBA  SG  23  23   923  234   511  ...  112  138  126
# 90  2010-11   32  LAL  NBA  SG  10  10   354   83   186  ...   26   34   33
# 91  2011-12   33  LAL  NBA  SG  12  12   476  132   301  ...   42   58   52
#
# ...

# %% [markdown]
# ##### 2. To display the first five rows from the dataset.

# %%
advst.head()
# Out:
#     Season  Age   Tm   Lg Pos   G  GS    MP   FG   FGA  ...  DRB  TRB  AST  \
# 0  2003-04   19  CLE  NBA  SG  79  79  3122  622  1492  ...  333  432  465
# 1  2004-05   20  CLE  NBA  SF  80  80  3388  795  1684  ...  477  588  577
# 2  2005-06   21  CLE  NBA  SF  79  79  3361  875  1823  ...  481  556  521
# 3  2006-07   22  CLE  NBA  SF  78  78  3190  772  1621  ...  443  526  470
# 4  2007-08   23  CLE  NBA  SF  75  74  3027  794  1642  ...  459  592  539
#
#    STL  BLK  TOV   PF   PTS        Player          RSorPO
# 0  130   58  273  149  1654  Lebron James  Regular Season
# 1  177   52  262  146  2175  Lebron James  Regular Season
# 2  123   66  260  181  2478  Lebron James  Regular Season
# 3  125   55  250  171  2132  Lebron James  Regular Season
# 4  138   81  255  165  2250  Lebron James  Regular Season
#
# [5 rows x 32 columns]

# %% [markdown]
# #### 3. To display last five rows from the dataset.

# %%
advst.tail()
# Out:
#      Season  Age   Tm   Lg Pos   G  GS   MP   FG  FGA  ...  DRB  TRB  AST  \
# 87  2007-08   29  LAL  NBA  SG  21  21  863  222  463  ...  101  119  117
# 88  2008-09   30  LAL  NBA  SG  23  23  940  242  530  ...  104  123  126
# 89  2009-10   31  LAL  NBA  SG  23  23  923  234  511  ...  112  138  126
# 90  2010-11   32  LAL  NBA  SG  10  10  354   83  186  ...   26   34   33
# 91  2011-12   33  LAL  NBA  SG  12  12  476  132  301  ...   42   58   52
#
#     STL  BLK  TOV  PF  PTS       Player    RSorPO
# 87   35    8   70  59  633  Kobe Bryant  Playoffs
# 88   38   21   59  59  695  Kobe Bryant  Playoffs
# 89   31   16   79  75  671  Kobe Bryant  Playoffs
# 90   16    3   31  23  228  Kobe Bryant  Playoffs
# 91   16    2   34  33  360  Kobe Bryant  Playoffs
#
# [5 rows x 32 columns]

# %% [markdown]
# #### 4. To display the datatypes of the entries.

# %%
advst.dtypes
# Out:
# Season     object
# Age         int64
# Tm         object
# Lg         object
# Pos        object
# G           int64
# GS          int64
# MP          int64
# FG          int64
# FGA         int64
# FG%       float64
# 3P          int64
# 3PA         int64
# 3P%       float64
# 2P          int64
# 2PA         int64
# 2P%       float64
# eFG%      float64
# FT          int64
# FTA         int64
# FT%       float64
# ORB         int64
# DRB         int64
# TRB         int64
# AST         int64
# STL         int64
# BLK         int64
# TOV         int64
# PF          int64
# PTS         int64
# Player     object
# RSorPO     object
# dtype: object

# %% [markdown]
# ##### 5. To display the number of entries and information in the dataset.

# %%
advst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 32 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  92 non-null     object
#  1   Age     92 non-null     int64
#  2   Tm      92 non-null     object
#  3   Lg      92 non-null     object
#  4   Pos     92 non-null     object
#  5   G       92 non-null     int64
#  6   GS      92 non-null     int64
#  7   MP      92 non-null     int64
#  8   FG      92 non-null     int64
#  9   FGA     92 non-null     int64
#  10  FG%     92 non-null     float64
#  11  3P      92 non-null     int64
#  12  3PA     92 non-null     int64
#  13  3P%     92 non-null     float64
#  14  2P      92 non-null     int64
#  15  2PA     92 non-null     int64
#  16  2P%     92 non-null     float64
#  17  eFG%    92 non-null     float64
#  18  FT      92 non-null     int64
#  19  FTA     92 non-null     int64
#  20  FT%     92 non-null     float64
# ...

# %% [markdown]
# #### 6. To display the detailed information and description of the dataset.

# %%
advst.describe()
# Out:
#              Age          G         GS           MP           FG          FGA  \
# count  92.000000  92.000000  92.000000    92.000000    92.000000    92.000000
# mean   27.108696  46.239130  44.043478  1761.380435   460.956522   958.880435
# std     5.004298  30.807581  31.285257  1175.946659   329.107381   664.597306
# min    18.000000   3.000000   0.000000   128.000000    21.000000    55.000000
# 25%    23.000000  17.750000  16.750000   712.000000   174.000000   382.000000
# 50%    27.000000  52.500000  29.000000  1535.000000   326.000000   746.000000
# 75%    31.000000  79.000000  78.000000  3028.000000   767.250000  1595.500000
# max    39.000000  82.000000  82.000000  3401.000000  1098.000000  2279.000000
#
#              FG%         3P         3PA        3P%  ...        FT%  \
# count  92.000000   92.00000   92.000000  92.000000  ...  92.000000
# mean    0.473446   53.75000  160.826087   0.328196  ...   0.800185
# ...

# %% [markdown]
# #### 7. To remove unwanted column.

# %%
advst.drop(["GS"], axis=1 , inplace = True)
advst
# Out:
#      Season  Age   Tm   Lg Pos   G    MP   FG   FGA    FG%  ...  DRB  TRB  \
# 0   2003-04   19  CLE  NBA  SG  79  3122  622  1492  0.417  ...  333  432
# 1   2004-05   20  CLE  NBA  SF  80  3388  795  1684  0.472  ...  477  588
# 2   2005-06   21  CLE  NBA  SF  79  3361  875  1823  0.480  ...  481  556
# 3   2006-07   22  CLE  NBA  SF  78  3190  772  1621  0.476  ...  443  526
# 4   2007-08   23  CLE  NBA  SF  75  3027  794  1642  0.484  ...  459  592
# ..      ...  ...  ...  ...  ..  ..   ...  ...   ...    ...  ...  ...  ...
# 87  2007-08   29  LAL  NBA  SG  21   863  222   463  0.479  ...  101  119
# 88  2008-09   30  LAL  NBA  SG  23   940  242   530  0.457  ...  104  123
# 89  2009-10   31  LAL  NBA  SG  23   923  234   511  0.458  ...  112  138
# 90  2010-11   32  LAL  NBA  SG  10   354   83   186  0.446  ...   26   34
# 91  2011-12   33  LAL  NBA  SG  12   476  132   301  0.439  ...   42   58
#
#     AST  STL  BLK  TOV   PF   PTS        Player          RSorPO
# ...

# %% [markdown]
# #### 8. To display the NaN values.

# %%
advst.isna().sum()
# Out:
# Season    0
# Age       0
# Tm        0
# Lg        0
# Pos       0
# G         0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# eFG%      0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# Player    0
# RSorPO    0
# dtype: int64

# %% [markdown]
# #### 8. To display the shape of the dataset.

# %%
advst.shape
# Out:
# (92, 31)

# %%
len(advst)
# Out:
# 92

# %% [markdown]
# #### 10. To display the detailed information about non numerical data of the dataset.

# %%
advst.describe(include='object')
# Out:
#          Season   Tm   Lg Pos       Player          RSorPO
# count        92   92   92  92           92              92
# unique       34    5    1   3            3               2
# top     2005-06  LAL  NBA  SG  Kobe Bryant  Regular Season
# freq          4   36   92  61           35              51

# %% [markdown]
# #### 11.How many unique players are there is data set

# %%
advst['Player'].nunique()
# Out:
# 3

# %%
advst['Player'].unique()
# Out:
# array(['Lebron James', 'Michael Jordan', 'Kobe Bryant'], dtype=object)

# %% [markdown]
# #### 12.For which team these players have played for in their entrie career

# %%
advst[advst.Player=='Lebron James'].Tm.unique()
# Out:
# array(['CLE', 'MIA', 'LAL'], dtype=object)

# %%
advst[advst.Player=='Kobe Bryant'].Tm.unique()
# Out:
# array(['LAL'], dtype=object)

# %%
advst[advst.Player=='Michael Jordan'].Tm.unique()
# Out:
# array(['CHI', 'WAS'], dtype=object)

# %% [markdown]
# #### 13.Collectine the data for each individual player

# %%
lebron=advst.loc[advst['Player']=='Lebron James']
lebron
# Out:
#      Season  Age   Tm   Lg Pos   G    MP   FG   FGA    FG%  ...  DRB  TRB  \
# 0   2003-04   19  CLE  NBA  SG  79  3122  622  1492  0.417  ...  333  432
# 1   2004-05   20  CLE  NBA  SF  80  3388  795  1684  0.472  ...  477  588
# 2   2005-06   21  CLE  NBA  SF  79  3361  875  1823  0.480  ...  481  556
# 3   2006-07   22  CLE  NBA  SF  78  3190  772  1621  0.476  ...  443  526
# 4   2007-08   23  CLE  NBA  SF  75  3027  794  1642  0.484  ...  459  592
# 5   2008-09   24  CLE  NBA  SF  81  3054  789  1613  0.489  ...  507  613
# 6   2009-10   25  CLE  NBA  SF  76  2966  768  1528  0.503  ...  483  554
# 7   2010-11   26  MIA  NBA  SF  79  3063  758  1485  0.510  ...  510  590
# 8   2011-12   27  MIA  NBA  SF  62  2326  621  1169  0.531  ...  398  492
# 9   2012-13   28  MIA  NBA  PF  76  2877  765  1354  0.565  ...  513  610
# 10  2013-14   29  MIA  NBA  PF  77  2902  767  1353  0.567  ...  452  533
# 11  2014-15   30  CLE  NBA  SF  69  2493  624  1279  0.488  ...  365  416
# ...

# %%
kobe=advst.loc[advst['Player']=='Kobe Bryant']
kobe
# Out:
#      Season  Age   Tm   Lg Pos   G    MP   FG   FGA    FG%  ...  DRB  TRB  \
# 57  1996-97   18  LAL  NBA  SG  71  1103  176   422  0.417  ...   85  132
# 58  1997-98   19  LAL  NBA  SG  79  2056  391   913  0.428  ...  163  242
# 59  1998-99   20  LAL  NBA  SG  50  1896  362   779  0.465  ...  211  264
# 60  1999-00   21  LAL  NBA  SG  66  2524  554  1183  0.468  ...  308  416
# 61  2000-01   22  LAL  NBA  SG  68  2783  701  1510  0.464  ...  295  399
# 62  2001-02   23  LAL  NBA  SG  80  3063  749  1597  0.469  ...  329  441
# 63  2002-03   24  LAL  NBA  SG  82  3401  868  1924  0.451  ...  458  564
# 64  2003-04   25  LAL  NBA  SG  65  2447  516  1178  0.438  ...  256  359
# 65  2004-05   26  LAL  NBA  SG  66  2689  573  1324  0.433  ...  297  392
# 66  2005-06   27  LAL  NBA  SG  80  3277  978  2173  0.450  ...  354  425
# 67  2006-07   28  LAL  NBA  SG  77  3140  813  1757  0.463  ...  364  439
# 68  2007-08   29  LAL  NBA  SG  82  3192  775  1690  0.459  ...  423  517
# ...

# %%
jordan=advst.loc[advst['Player']=='Michael Jordan']
jordan
# Out:
#      Season  Age   Tm   Lg Pos   G    MP    FG   FGA    FG%  ...  DRB  TRB  \
# 29  1984-85   21  CHI  NBA  SG  82  3144   837  1625  0.515  ...  367  534
# 30  1985-86   22  CHI  NBA  SG  18   451   150   328  0.457  ...   41   64
# 31  1986-87   23  CHI  NBA  SG  82  3281  1098  2279  0.482  ...  264  430
# 32  1987-88   24  CHI  NBA  SG  82  3311  1069  1998  0.535  ...  310  449
# 33  1988-89   25  CHI  NBA  SG  81  3255   966  1795  0.538  ...  503  652
# 34  1989-90   26  CHI  NBA  SG  82  3197  1034  1964  0.526  ...  422  565
# 35  1990-91   27  CHI  NBA  SG  82  3034   990  1837  0.539  ...  374  492
# 36  1991-92   28  CHI  NBA  SG  80  3102   943  1818  0.519  ...  420  511
# 37  1992-93   29  CHI  NBA  SG  78  3067   992  2003  0.495  ...  387  522
# 38  1994-95   31  CHI  NBA  SG  17   668   166   404  0.411  ...   92  117
# 39  1995-96   32  CHI  NBA  SG  82  3090   916  1850  0.495  ...  395  543
# ...

# %% [markdown]
# #### 14.How many minutes they have played?

# %%
advst.groupby('Player').sum()['MP']
# Out:
# Player
# Kobe Bryant       57278
# Lebron James      56284
# Michael Jordan    48485
# Name: MP, dtype: int64

# %% [markdown]
# #### 15.How many games they have played?

# %%
advst.groupby('Player').sum()['G']
# Out:
# Player
# Kobe Bryant       1566
# Lebron James      1437
# Michael Jordan    1251
# Name: G, dtype: int64

# %% [markdown]
# #### 16.How many points they have scored?

# %%
advst.groupby('Player').sum()['PTS']
# Out:
# Player
# Kobe Bryant       39283
# Lebron James      39454
# Michael Jordan    38279
# Name: PTS, dtype: int64

# %% [markdown]
# #### 17.To display the average pionts scored along with highest in season and lowest in season

# %%
advst.groupby('Player').agg(['mean','min','max']).PTS
# Out:
#                        mean  min   max
# Player
# Kobe Bryant     1122.371429   74  2832
# Lebron James    1360.482759  320  2478
# Michael Jordan  1367.107143  107  3041

# %% [markdown]
# #### 18.To display the average minutes played in a season along with highest in season and lowest in season

# %%
advst.groupby('Player').agg(['mean','min','max']).MP
# Out:
#                        mean  min   max
# Player
# Kobe Bryant     1636.514286  133  3401
# Lebron James    1940.827586  460  3388
# Michael Jordan  1731.607143  128  3311

# %% [markdown]
# #### 18.To display the average games played in season along with highest in season and lowest in season

# %%
advst.groupby('Player').agg(['mean','min','max']).G
# Out:
#                      mean  min  max
# Player
# Kobe Bryant     44.742857    5   82
# Lebron James    49.551724   11   82
# Michael Jordan  44.678571    3   82

# %% [markdown]
# ##### 20.Sorting values

# %% [markdown]
# # LET'S COMPARE THE DEFENSIVE STATS OF EACH PLAYER TO SEE WHO WAS A GOOD DEFENDER

# %%
advst.sort_values('BLK',ascending=False).head(30)
# Out:
#      Season  Age   Tm   Lg Pos   G    MP    FG   FGA    FG%  ...  DRB  TRB  \
# 32  1987-88   24  CHI  NBA  SG  82  3311  1069  1998  0.535  ...  310  449
# 31  1986-87   23  CHI  NBA  SG  82  3281  1098  2279  0.482  ...  264  430
# 5   2008-09   24  CLE  NBA  SF  81  3054   789  1613  0.489  ...  507  613
# 35  1990-91   27  CHI  NBA  SG  82  3034   990  1837  0.539  ...  374  492
# 4   2007-08   23  CLE  NBA  SF  75  3027   794  1642  0.484  ...  459  592
# 6   2009-10   25  CLE  NBA  SF  76  2966   768  1528  0.503  ...  483  554
# 36  1991-92   28  CHI  NBA  SG  80  3102   943  1818  0.519  ...  420  511
# 14  2017-18   33  CLE  NBA  PF  82  3026   857  1580  0.542  ...  612  709
# 29  1984-85   21  CHI  NBA  SG  82  3144   837  1625  0.515  ...  367  534
# 63  2002-03   24  LAL  NBA  SG  82  3401   868  1924  0.451  ...  458  564
# 9   2012-13   28  MIA  NBA  PF  76  2877   765  1354  0.565  ...  513  610
# ...

# %%
blk=advst[advst['BLK']>=50]
sns.countplot(data=blk,x="Player")
# Out:
# <AxesSubplot:xlabel='Player', ylabel='count'>

# %% [markdown]
#     Data shows that which player had 50 or more blocks per season in entrie career,"LBJ" had more than 10 such seasons compared to "MJ" and "KB" but if we look "MJ" had more than 100 blocks twice which "LBJ" and "KB" never achieved.

# %%
advst.sort_values('STL',ascending=False).head(30)
# Out:
#      Season  Age   Tm   Lg Pos   G    MP    FG   FGA    FG%  ...  DRB  TRB  \
# 32  1987-88   24  CHI  NBA  SG  82  3311  1069  1998  0.535  ...  310  449
# 31  1986-87   23  CHI  NBA  SG  82  3281  1098  2279  0.482  ...  264  430
# 33  1988-89   25  CHI  NBA  SG  81  3255   966  1795  0.538  ...  503  652
# 34  1989-90   26  CHI  NBA  SG  82  3197  1034  1964  0.526  ...  422  565
# 35  1990-91   27  CHI  NBA  SG  82  3034   990  1837  0.539  ...  374  492
# 37  1992-93   29  CHI  NBA  SG  78  3067   992  2003  0.495  ...  387  522
# 29  1984-85   21  CHI  NBA  SG  82  3144   837  1625  0.515  ...  367  534
# 36  1991-92   28  CHI  NBA  SG  80  3102   943  1818  0.519  ...  420  511
# 63  2002-03   24  LAL  NBA  SG  82  3401   868  1924  0.451  ...  458  564
# 39  1995-96   32  CHI  NBA  SG  82  3090   916  1850  0.495  ...  395  543
# 1   2004-05   20  CLE  NBA  SF  80  3388   795  1684  0.472  ...  477  588
# ...

# %%
stl=advst[advst['STL']>=120]
sns.countplot(data=stl,x="Player")
# Out:
# <AxesSubplot:xlabel='Player', ylabel='count'>

# %% [markdown]
#     Data shows that which player had 120 or more steals per season in entrie career,"MJ" had more than 12  seasons compared to "LBJ" and "KB" and also "MJ" had more than 200 steals 6 times.So "MJ" was an active defender

# %%
advst.sort_values('DRB',ascending=False).head(30)
# Out:
#      Season  Age   Tm   Lg Pos   G    MP    FG   FGA    FG%  ...  DRB  TRB  \
# 14  2017-18   33  CLE  NBA  PF  82  3026   857  1580  0.542  ...  612  709
# 13  2016-17   32  CLE  NBA  SF  74  2794   736  1344  0.548  ...  542  639
# 9   2012-13   28  MIA  NBA  PF  76  2877   765  1354  0.565  ...  513  610
# 7   2010-11   26  MIA  NBA  SF  79  3063   758  1485  0.510  ...  510  590
# 5   2008-09   24  CLE  NBA  SF  81  3054   789  1613  0.489  ...  507  613
# 33  1988-89   25  CHI  NBA  SG  81  3255   966  1795  0.538  ...  503  652
# 6   2009-10   25  CLE  NBA  SF  76  2966   768  1528  0.503  ...  483  554
# 2   2005-06   21  CLE  NBA  SF  79  3361   875  1823  0.480  ...  481  556
# 1   2004-05   20  CLE  NBA  SF  80  3388   795  1684  0.472  ...  477  588
# 4   2007-08   23  CLE  NBA  SF  75  3027   794  1642  0.484  ...  459  592
# 63  2002-03   24  LAL  NBA  SG  82  3401   868  1924  0.451  ...  458  564
# ...

# %%
drb=advst[advst['DRB']>=500]
sns.countplot(data=stl,x="Player")
# Out:
# <AxesSubplot:xlabel='Player', ylabel='count'>

# %% [markdown]
#     Defensive rebound is also an important parameter to show who was good in defense as shown above "MJ" 12 seasons where grabbed more than 500 rebounds,"LBJ" had 10 seasons and "KB" had 4 seasons in his career

# %% [markdown]
# ##### >So in terms of defensive record both "MJ" and "LBJ" were on equal terms, whereas "KB" was a good defender but not as same as his other counterparts

# %% [markdown]
# # NOW LET'S COMPARE OFFENSIVE PART OF THE PLAYERS GAME

# %%
advst.groupby('Player').agg(['mean','min','max']).FGA
# Out:
#                        mean  min   max
# Player
# Kobe Bryant      877.114286   55  2173
# Lebron James     982.206897  211  1823
# Michael Jordan  1036.928571   78  2279

# %%
advst.groupby('Player').agg(['mean','min','max']).FG
# Out:
#                       mean  min   max
# Player
# Kobe Bryant     392.371429   21   978
# Lebron James    492.931034  106   875
# Michael Jordan  513.571429   34  1098

# %% [markdown]
#     As shown above most field goal attempted by player is "MJ" and then by "KB" while least attempted is "LBJ" cause "LBJ" used to play as power forward while 'MJ' and 'KB' used to play as Shooting guard
#     Further field goal 'MJ' has made more than 1000 field goals compared to 'KB' and 'LBJ'

# %%
points = lebron['PTS']
ids = lebron['Season']

plt.barh(year,points)
plt.xlabel("Points")
plt.ylabel("Season")
plt.title("Lebron per season points")
plt.grid(True)
plt.show()

# %%
points = kobe['PTS']
year = kobe['Season']

plt.barh(year,points)
plt.xlabel("Points")
plt.ylabel("Season")
plt.title("Kobe per season points")
plt.grid(True)
plt.show()

# %%
points = jordan['PTS']
year = jordan['Season']

plt.barh(year,points)
plt.xlabel("Points")
plt.ylabel("Season")
plt.title("Jordan per season points")
plt.grid(True)
plt.show()

# %%
pts2000=advst[advst['PTS']>=2000]
pts2000['Player'].value_counts()
# Out:
# Michael Jordan    11
# Lebron James      10
# Kobe Bryant        8
# Name: Player, dtype: int64

# %%
sns.countplot(data=pts2000,x='Player')
# Out:
# <AxesSubplot:xlabel='Player', ylabel='count'>

# %% [markdown]
# ##### This shows us that "MJ" was better scorer than other player

# %% [markdown]
#     As "MJ" has more than 10 season where he scored more than 2000 points in single season,whereas 'LBJ' had 10 seasons and 'KB' had 8 such seasons

# %%
asst=advst[advst['AST']>=400]
asst['Player'].value_counts()
# Out:
# Lebron James      15
# Michael Jordan     7
# Kobe Bryant        5
# Name: Player, dtype: int64

# %%
sns.countplot(data=asst,x='Player')
# Out:
# <AxesSubplot:xlabel='Player', ylabel='count'>

# %% [markdown]
#     As everyone knows out of these 3 'LBJ' is good passer and numbers also proves the same as he has more than 14 seasons where he has helped teamates the score with the ball more than 400 times and 'MJ' comes second and 'KB' third

# %%
offrb=advst[advst['ORB']>=100]
offrb['Player'].value_counts()
# Out:
# Michael Jordan    10
# Kobe Bryant        5
# Lebron James       4
# Name: Player, dtype: int64

# %%
sns.countplot(data=offrb,x='Player')
# Out:
# <AxesSubplot:xlabel='Player', ylabel='count'>

# %% [markdown]
# ##### "MJ" was better a offensive rebounder

# %% [markdown]
# # Conclusion -
#     After visualizing the data we can see that Michael Jordan has the best career with regards to average Points Scored per Season. However, Kobe takes the crown for the most points scored, and Lebron has had a consistant career with several more years still possible.
